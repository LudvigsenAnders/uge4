# %%
from pathlib import Path


# Current file's directory
cwd = Path.cwd()

path = cwd.parent.parent

file_path = path/'data'/'Navneliste.txt'

# %%
print(file_path)
# Out:
# c:\Users\Anders Ludvigsen\OneDrive - Specialisterne\Dokumenter\GitHub\uge4\data\Navneliste.txt

# %%
with open(file_path, encoding="utf-8") as f:
    read_data = f.read()

# %%
names = [ name.strip() for name in read_data.split(',')]

# %%
names_sorted_by_char = sorted(names, key=str.lower)

# %%
names_sorted_by_len = sorted(names, key=len)

# %%
my_char_dict = {}

# %%
for name in names:
    for char in name:
        char = char.lower()
        if char not in my_char_dict:
            my_char_dict[char] = 1
        else:
            my_char_dict[char] += 1

# %%
# We can check that the file has been automatically closed.
f.closed
# Out:
# True

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'
