# %%
import pandas as pd
from pathlib import Path

# %%
path = Path.cwd().resolve().parents[1]
print(path)
path_housing = path / "data" / "DKHousingPricesSample100k.csv"
path_out = path / "data" / "csv_output"
# Out:
# C:\Users\Anders Ludvigsen\OneDrive - Specialisterne\Dokumenter\GitHub\uge4

# %%
df = pd.read_csv(
    path_housing,
    sep=",",
    header=0,
    index_col=False,
    on_bad_lines='warn',
    dtype={
        "date": "string",
        "quarter": "string",
        "house_id": "int64",
        "house_type": "string",
        "sales_type": "string",
        "year_build": "int64",
        "purchase_price": "float64",
        "%_change_between_offer_and_purchase": "float64",
        "no_rooms": "int64",
        "sqm": "float64",
        "sqm_price": "float64",
        "address": "string",
        "zip_code": "int64",
        "city": "string",
        "area": "string",
        "region": "string",
        "%_nom_interest_rate%": float,
        "%_dk_ann_infl_rate%": float,
        "%_yield_on_mortgage_credit_bonds%": float
    }
)

df['date'] = pd.to_datetime(df['date'], errors='coerce', format='%Y-%m-%d').dt.date
df['quarter'] = pd.PeriodIndex(df['quarter'], freq='Q')

# %%
print(df.head(10))

df_region_grp = df.groupby('region')['purchase_price'].agg(['mean', 'median', 'std', 'min', 'max'])

print(df.info())
print(df.describe(include='all'))
# Out:
#          date quarter  house_id   house_type    sales_type  year_build  \
# 0  2024-10-24  2024Q4        16        Villa  regular_sale        1997
# 1  2024-10-24  2024Q4        13    Apartment  regular_sale        1885
# 2  2024-10-23  2024Q4        60        Villa  regular_sale        1949
# 3  2024-10-23  2024Q4        29        Villa  regular_sale        2001
# 4  2024-10-22  2024Q4        92    Apartment  regular_sale        1965
# 5  2024-10-22  2024Q4        82        Villa  regular_sale        1858
# 6  2024-10-22  2024Q4       100  Summerhouse  regular_sale        1970
# 7  2024-10-21  2024Q4       125    Townhouse   family_sale        1980
# 8  2024-10-20  2024Q4       150        Villa  regular_sale        1943
# 9  2024-10-18  2024Q4       177        Villa  regular_sale        1976
#
#    purchase_price  %_change_between_offer_and_purchase  no_rooms    sqm  \
# 0       6500000.0                                 -3.0         5  142.0
# 1       3400000.0                                  0.0         2   46.0
# 2       4550000.0                                 -4.0         4  112.0
# 3       1630000.0                                -12.0         4  186.0
# 4       1975000.0                                -10.0         3   82.0
# 5       1850000.0                                  0.0         5  154.0
# 6        360000.0                                  0.0         3   42.0
# 7        700000.0                                  0.0         2   62.0
# 8        500000.0                                  0.0         6  202.0
# 9        850000.0                                -13.0         4  118.0
#
#     sqm_price                          address  zip_code             city  \
# 0  45774.6500                     Spættevej 16      2680    Solrød Strand
# 1  73913.0500  Jakob Dannefærds Vej 10B, 4. th      1973  Frederiksberg C
# 2  40625.0000             Vestre Plantagevej 3      2680    Solrød Strand
# 3   8763.4400                     Toftebjerg 3      4400       Kalundborg
# 4  24085.3650        Ryttergårdsvej 20, 1. 113      3520            Farum
# 5  12012.9870                  Lehnskovvej 220      5700        Svendborg
# 6   8571.4290                       Alkærvej 9      2740        Skovlunde
# 7  11290.3220                     Kirkebyen 3F      7950           Erslev
# 8   2475.2476                     Smedegade 15      6535      Branderup J
# 9   7203.3896                    Overmarken 26      6670          Holsted
#
#                   area         region  nom_interest_rate%  dk_ann_infl_rate%  \
# 0  Capital, Copenhagen        Zealand                 3.1                NaN
# 1  Capital, Copenhagen        Zealand                 3.1                NaN
# 2  Capital, Copenhagen        Zealand                 3.1                NaN
# 3        Other islands        Zealand                 3.1                NaN
# 4        North Zealand        Zealand                 3.1                NaN
# 5        Fyn & islands  Fyn & islands                 3.1                NaN
# 6  Capital, Copenhagen        Zealand                 3.1                NaN
# 7        South jutland        Jutland                 3.1                NaN
# 8        South jutland        Jutland                 3.1                NaN
# 9        South jutland        Jutland                 3.1                NaN
#
#    yield_on_mortgage_credit_bonds%
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   date                                 100000 non-null  object
#  1   quarter                              100000 non-null  period[Q-DEC]
#  2   house_id                             100000 non-null  int64
#  3   house_type                           100000 non-null  string
#  4   sales_type                           100000 non-null  string
#  5   year_build                           100000 non-null  int64
#  6   purchase_price                       100000 non-null  float64
#  7   %_change_between_offer_and_purchase  100000 non-null  float64
#  8   no_rooms                             100000 non-null  int64
#  9   sqm                                  100000 non-null  float64
#  10  sqm_price                            100000 non-null  float64
#  11  address                              100000 non-null  string
#  12  zip_code                             100000 non-null  int64
#  13  city                                 99989 non-null   string
#  14  area                                 100000 non-null  string
#  15  region                               100000 non-null  string
#  16  nom_interest_rate%                   100000 non-null  float64
#  17  dk_ann_infl_rate%                    99923 non-null   float64
#  18  yield_on_mortgage_credit_bonds%      99923 non-null   float64
# dtypes: float64(7), int64(4), object(1), period[Q-DEC](1), string(6)
# memory usage: 14.5+ MB
# None
#               date quarter      house_id house_type    sales_type  \
# count       100000  100000  1.000000e+05     100000        100000
# unique       11254     130           NaN          5             4
# top     2023-12-19  2021Q1           NaN      Villa  regular_sale
# freq            49    2263           NaN      54214         88232
# mean           NaN     NaN  7.531364e+05        NaN           NaN
# std            NaN     NaN  4.348902e+05        NaN           NaN
# min            NaN     NaN  1.300000e+01        NaN           NaN
# 25%            NaN     NaN  3.770722e+05        NaN           NaN
# 50%            NaN     NaN  7.511035e+05        NaN           NaN
# 75%            NaN     NaN  1.128904e+06        NaN           NaN
# max            NaN     NaN  1.507901e+06        NaN           NaN
#
#            year_build  purchase_price  %_change_between_offer_and_purchase  \
# count   100000.000000    1.000000e+05                        100000.000000
# unique            NaN             NaN                                  NaN
# top               NaN             NaN                                  NaN
# freq              NaN             NaN                                  NaN
# mean      1955.078530    1.925992e+06                            -2.084740
# std         45.703585    1.777832e+06                             4.852926
# min       1000.000000    2.502000e+05                           -49.000000
# 25%       1931.000000    8.000000e+05                            -3.000000
# 50%       1966.000000    1.400000e+06                             0.000000
# 75%       1980.000000    2.450000e+06                             0.000000
# max       2024.000000    4.595500e+07                            49.000000
#
#              no_rooms            sqm      sqm_price    address       zip_code  \
# count   100000.000000  100000.000000  100000.000000     100000  100000.000000
# unique            NaN            NaN            NaN      92463            NaN
# top               NaN            NaN            NaN  Vibevej 2            NaN
# freq              NaN            NaN            NaN         12            NaN
# mean         4.375790     129.387820   16406.648074        NaN    5951.612680
# std          1.661686      57.170619   13655.184405        NaN    2369.938171
# min          1.000000      26.000000     374.549800        NaN    1051.000000
# 25%          3.000000      89.000000    6792.940775        NaN    4000.000000
# 50%          4.000000     123.000000   12070.707000        NaN    5970.000000
# 75%          5.000000     160.000000   21343.201500        NaN    8250.000000
# max         15.000000     984.000000   75000.000000        NaN    9990.000000
#
#                city           area   region  nom_interest_rate%  \
# count         99989         100000   100000       100000.000000
# unique          607              8        4                 NaN
# top     København S  South jutland  Jutland                 NaN
# freq           1275          22563    49937                 NaN
# mean            NaN            NaN      NaN            1.679263
# std             NaN            NaN      NaN            2.048078
# min             NaN            NaN      NaN            0.000000
# 25%             NaN            NaN      NaN            0.000000
# 50%             NaN            NaN      NaN            0.750000
# 75%             NaN            NaN      NaN            3.250000
# max             NaN            NaN      NaN            9.500000
#
#         dk_ann_infl_rate%  yield_on_mortgage_credit_bonds%
# count        99923.000000                     99923.000000
# unique                NaN                              NaN
# top                   NaN                              NaN
# freq                  NaN                              NaN
# mean             1.927025                         4.107445
# std              1.638440                         2.194428
# min              0.250000                         1.100000
# 25%              0.790000                         2.120000
# 50%              1.850000                         4.340000
# 75%              2.340000                         5.500000
# max              7.700000                        10.140000
